# %% [markdown]
# ### Reading and dispalying the csv file

# %%
import pandas as pd
file = "C:\\Users\\ruchitha\\Downloads\\un-general-debates-blueprint.csv"
df = pd.read_csv(file)
df.head(20)
# Out:
#     session  year country                     country_name  \
# 0        25  1970     ALB                          Albania
# 1        25  1970     ARG                        Argentina
# 2        25  1970     AUS                        Australia
# 3        25  1970     AUT                          Austria
# 4        25  1970     BEL                          Belgium
# 5        25  1970     BLR                          Belarus
# 6        25  1970     BOL  Bolivia, Plurinational State of
# 7        25  1970     BRA                           Brazil
# 8        25  1970     CAN                           Canada
# 9        25  1970     CMR                         Cameroon
# 10       25  1970     COG                            Congo
# 11       25  1970     COL                         Colombia
# 12       25  1970     CRI                       Costa Rica
# 13       25  1970     CUB                             Cuba
# 14       25  1970     DOM               Dominican Republic
# ...

# %%
#This will open the file and then randomly pick 20% of the records.
#df = df.sample(frac=0.2)
#df

# %% [markdown]
# #### Columns- displays the names of columns in the dataframe

# %%
df.columns
# Out:
# Index(['session', 'year', 'country', 'country_name', 'speaker', 'position',
#        'text'],
#       dtype='object')

# %% [markdown]
# #### The dtypes- returns the data types of columns in the dataframe

# %%
df.dtypes
# Out:
# session          int64
# year             int64
# country         object
# country_name    object
# speaker         object
# position        object
# text            object
# dtype: object

# %% [markdown]
# #### The info() menthod prints the information of the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7507 entries, 0 to 7506
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   session       7507 non-null   int64
#  1   year          7507 non-null   int64
#  2   country       7507 non-null   object
#  3   country_name  7507 non-null   object
#  4   speaker       7480 non-null   object
#  5   position      4502 non-null   object
#  6   text          7507 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 410.7+ KB

# %% [markdown]
# #### The describe() method returns statistical data of the dataframe

# %%
df.describe()
# Out:
#            session         year
# count  7507.000000  7507.000000
# mean     49.610763  1994.610763
# std      12.892155    12.892155
# min      25.000000  1970.000000
# 25%      39.000000  1984.000000
# 50%      51.000000  1996.000000
# 75%      61.000000  2006.000000
# max      70.000000  2015.000000

# %% [markdown]
# #### Creating a new column 'length' in dataframe and assigning it the length of each string of the 'text' column

# %%
df['length'] = df['text'].str.len()
df.describe() #Calculates statistical data of the dataframe
# Out:
#            session         year        length
# count  7507.000000  7507.000000   7507.000000
# mean     49.610763  1994.610763  17967.281604
# std      12.892155    12.892155   7860.038463
# min      25.000000  1970.000000   2362.000000
# 25%      39.000000  1984.000000  12077.000000
# 50%      51.000000  1996.000000  16424.000000
# 75%      61.000000  2006.000000  22479.500000
# max      70.000000  2015.000000  72041.000000

# %% [markdown]
# #### Gives an overview of the data in the dataframe which includes the most common values and their frequencies.

# %%
df.describe(include='O')
# Out:
#        country country_name        speaker                      position  \
# count     7507         7507           7480                          4502
# unique     199          199           5428                           113
# top        ALB      Albania  Seyoum Mesfin  Minister for Foreign Affairs
# freq        46           46             12                          1813
#
#                                                      text
# count                                                7507
# unique                                               7507
# top     33: May I first convey to our President the co...
# freq                                                    1

# %% [markdown]
# #### This returns the count of missing values for each column in the dataframe

# %%
df.isna().sum()
# Out:
# session            0
# year               0
# country            0
# country_name       0
# speaker           27
# position        3005
# text               0
# length             0
# dtype: int64

# %% [markdown]
# #### Filling in missing values in the 'speaker' and 'position' columns with 'unknown'.

# %%
df['speaker'].fillna('unknown', inplace=True)
df['position'].fillna('unknown', inplace=True)
df.isna().sum()
# Out:
# session         0
# year            0
# country         0
# country_name    0
# speaker         0
# position        0
# text            0
# length          0
# dtype: int64

# %% [markdown]
# #### Converting the values in the 'speaker', 'position', and 'text' columns of the DataFrame to uppercase using the upper() method

# %%
df['speaker'] = df['speaker'].str.upper()
df['position'] = df['position'].str.upper()
df['text'] = df['text'].str.upper()
df.head(20)#Displaying first 20 rows of the DataFrame
# Out:
#     session  year country                     country_name  \
# 0        25  1970     ALB                          Albania
# 1        25  1970     ARG                        Argentina
# 2        25  1970     AUS                        Australia
# 3        25  1970     AUT                          Austria
# 4        25  1970     BEL                          Belgium
# 5        25  1970     BLR                          Belarus
# 6        25  1970     BOL  Bolivia, Plurinational State of
# 7        25  1970     BRA                           Brazil
# 8        25  1970     CAN                           Canada
# 9        25  1970     CMR                         Cameroon
# 10       25  1970     COG                            Congo
# 11       25  1970     COL                         Colombia
# 12       25  1970     CRI                       Costa Rica
# 13       25  1970     CUB                             Cuba
# 14       25  1970     DOM               Dominican Republic
# ...

# %% [markdown]
# #### Filtering DataFrame to find rows where the 'speaker' column contains the string 'BUSH'

# %%
df[df['speaker'].str.contains('BUSH')]
# Out:
#       session  year country   country_name             speaker   position  \
# 2720       44  1989     USA  United States                BUSH  PRESIDENT
# 2876       45  1990     USA  United States         GEORGE BUSH    UNKNOWN
# 3038       46  1991     USA  United States         GEORGE BUSH  PRESIDENT
# 3207       47  1992     USA  United States     MR. GEORGE BUSH  PRESIDENT
# 4814       56  2001     USA  United States      GEORGE W. BUSH  PRESIDENT
# 5002       57  2002     USA  United States  MR. GEORGE W. BUSH  PRESIDENT
# 5191       58  2003     USA  United States      GEORGE W. BUSH  PRESIDENT
# 5382       59  2004     USA  United States   MR. GEORGE W BUSH  PRESIDENT
# 5760       61  2006     USA  United States  MR. GEORGE W. BUSH  PRESIDENT
# 5951       62  2007     USA  United States      GEORGE W. BUSH  PRESIDENT
# 6143       63  2008     USA  United States      GEORGE W. BUSH  PRESIDENT
#
#                                                    text  length
# ...

# %% [markdown]
# #### Plotting line plot for the 'length' column

# %%
import matplotlib.pyplot as plt
df['length'].plot()
plt.xlabel('Index')
plt.ylabel('Length')
plt.title('Length Distribution')
plt.show()

# %% [markdown]
# #### Plotting horizontal box plot of the 'length' column

# %%
df['length'].plot(kind='box', vert=False)
plt.xlabel('Length')
plt.title('Length Distribution')
plt.show()

# %% [markdown]
# #### Plotting histogram of the 'length' column with 30 bins

# %%
df['length'].plot(kind='hist', bins=30)
plt.xlabel('Length')
plt.title('Length Distribution')
plt.show()

# %% [markdown]
# #### Generating a box plot showing the distribution of 'length' for each country ('USA', 'FRA', 'GBR', 'CHN', 'RUS')

# %%
import seaborn as sns 
where = df['country'].isin(['USA', 'FRA', 'GBR', 'CHN', 'RUS'])
g = sns.catplot(data=df[where], x="country", y="length", kind='box')
g.fig.set_size_inches(10, 8) ###
# Out:
# C:\Users\ruchitha\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #### This code extracts words from a given text while considering hyphens and ignoring non-alphanumeric characters

# %%
import regex as re

def tokenize(text):
    return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text)

testtext = "Let's defeat SARS-CoV-2 together in 2020! www.cdc.gov"
testtokens = tokenize(testtext)
 
print(testtokens)
# Out:
# ['Let', 's', 'defeat', 'SARS-CoV-2', 'together', 'in', 'www', 'cdc', 'gov']

# %% [markdown]
# #### Importing natural language tool kit package and displaying the stop words

# %%
import nltk 
nltk.download('stopwords')
stopwords = set(nltk.corpus.stopwords.words('english'))
print(stopwords)
# Out:
# {'than', 'only', 'into', "couldn't", "it's", 'out', 'my', 'here', 'had', 'so', 'both', 'doesn', "you'd", 'again', 'why', 'am', 'm', 'being', 'up', 're', "isn't", "shouldn't", 'i', 'how', 'below', 'yourselves', 'our', 'from', 'under', 'been', "shan't", "aren't", 'on', 'own', 'can', 'at', 'more', "won't", 'whom', 'very', 'll', 'where', "hasn't", 'during', 'hasn', 'herself', 'ourselves', 'are', 'not', 'wasn', 'with', 'yourself', 'a', 'mightn', "needn't", 'weren', 'themselves', 'and', 'aren', 'doing', 'in', 'nor', 'these', "she's", 'ain', 'hers', 'haven', 'himself', 'him', 'her', 'as', "mustn't", "didn't", 'will', 'then', "you'll", 'against', "haven't", 'didn', 'did', 't', 'other', 'by', 'now', 'do', 'couldn', 'some', 'between', 'those', 'ma', 'd', 'which', 'because', 'any', 'off', 'we', 'shan', 'theirs', 'itself', 'mustn', 'it', 'ours', 'its', 'me', 'hadn', 'you', 'after', 'be', "wasn't", 'his', 'wouldn', 'o', 'further', 've', 'he', 'were', 'an', 'if', 'through', 'isn', 'over', "weren't
# ...

# %% [markdown]
# #### Testing the function

# %%
def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords]
#Just testing it
cleantokens= remove_stop(testtokens)
print(cleantokens)
# Out:
# ['Let', 'defeat', 'SARS-CoV-2', 'together', 'www', 'cdc', 'gov']

# %% [markdown]
# #### The prepare function is to define pipeline that converts text to lowercase, tokenizes it, and removes stopwords

# %%
pipeline = [str.lower, tokenize, remove_stop]

def prepare(text, pipeline):
    tokens = text
    for fun in pipeline:
        tokens = fun(tokens)
    return tokens

# %% [markdown]
# #### Creates a new column 'tokens' in the DataFrame

# %%
df['tokens'] = df['text'].apply(prepare, pipeline=pipeline)

# %% [markdown]
# #### Creates a new column 'num_tokens' which calculates the number of tokens for each text entry in the 'tokens' column

# %%
df['num_tokens'] = df['tokens'].map(len)
df.tail(10) #Displays last 10 records of the DataFrame
# Out:
#       session  year country                       country_name  \
# 7497       70  2015     VCT   Saint Vincent and the Grenadines
# 7498       70  2015     VEN  Venezuela, Bolivarian Republic of
# 7499       70  2015     VNM                           Viet Nam
# 7500       70  2015     VUT                            Vanuatu
# 7501       70  2015     WSM                              Samoa
# 7502       70  2015     YEM                              Yemen
# 7503       70  2015     YUG                         Yugoslavia
# 7504       70  2015     ZAF                       South Africa
# 7505       70  2015     ZMB                             Zambia
# 7506       70  2015     ZWE                           Zimbabwe
#
#                                 speaker        position  \
# 7497                MR. RALPH GONSALVES  PRIME MINISTER
# 7498           MR. NICOLÁS MADURO MOROS       PRESIDENT
# 7499            MRS. NGUYEN PHUONG NGA       DELEGATION
# ...

# %% [markdown]
#  #### Counts the frequency of tokens in the given text

# %%
from collections import Counter

tokens = tokenize("She likes my cats and my cats like my sofa.")

testcount= Counter(tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 2, 'She': 1, 'likes': 1, 'and': 1, 'like': 1, 'sofa': 1})

# %% [markdown]
# #### Updating the token counts based on tokens from another text

# %%
more_tokens = tokenize("She likes dogs and cats.")
testcount.update(more_tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 3, 'She': 2, 'likes': 2, 'and': 2, 'like': 1, 'sofa': 1, 'dogs': 1})

# %% [markdown]
# #### Prints the most common 5 tokens and their frequencies across all entries in the 'tokens' column of the DataFrame

# %%
counter = Counter()
df['tokens'].map(counter.update)
print(counter.most_common(5))
# Out:
# [('nations', 124508), ('united', 120763), ('international', 117223), ('world', 89421), ('countries', 85734)]

# %% [markdown]
# #### Creating a DataFrame freq_df and filtering out tokens with a frequency of less than 1

# %%
freq_df = pd.DataFrame.from_dict(counter, orient='index', columns=['freq'])
freq_df = freq_df.query('freq >= 1')
freq_df.index.name = 'token'

# %% [markdown]
# #### Sorting DataFrame by freq column in descending order

# %%
freq_df = freq_df.sort_values('freq', ascending=False)
freq_df.head(10)#prints first 10 records of the DataFrame
# Out:
#                  freq
# token
# nations        124508
# united         120763
# international  117223
# world           89421
# countries       85734
# peace           72625
# development     62632
# states          59713
# people          59338
# security        58425

# %% [markdown]
# #### Returns statistical data of the freq_df DataFrame

# %%
freq_df.describe()
# Out:
#                 freq
# count   68302.000000
# mean      162.686276
# std      1544.080072
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%        15.000000
# max    124508.000000

# %% [markdown]
# #### Creating a horizontal bar plot using the top 15 most frequent tokens from freq_df DataFrame

# %%
ax = freq_df.head(15).plot(kind='barh', width=0.95, figsize=(12,8))
ax.invert_yaxis()
ax.set(xlabel='Frequency', ylabel='Token', title='Top Words')
# Out:
# [Text(0.5, 0, 'Frequency'), Text(0, 0.5, 'Token'), Text(0.5, 1.0, 'Top Words')]

# %%
pip install WordCloud
# Out:
# ...
#
#   Obtaining dependency information for WordCloud from https://files.pythonhosted.org/packages/f5/b0/247159f61c5d5d6647171bef84430b7efad4db504f0229674024f3a4f7f2/wordcloud-1.9.3-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/300.2 kB ? eta -:--:--
#    ------------------------------- -------- 235.5/300.2 kB 7.3 MB/s eta 0:00:01
#    ---------------------------------------- 300.2/300.2 kB 3.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# #### Visualization using the WordCloud library and matplotlib of the text data from the USA in the year 2015, with a maximum of 100 words.

# %%
from wordcloud import WordCloud
from matplotlib import pyplot as plt

text = df.query("year==2015 and country=='USA'")['text'].values[0]
plt.figure(figsize=(14, 7)) ###
wc = WordCloud(max_words=100, stopwords=stopwords)
wc.generate(text)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)
